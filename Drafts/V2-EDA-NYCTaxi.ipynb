# %% [markdown]
# # NYC Taxi Operations Analysis from TLC Data
# ---
#
# # **Overview**
# New York City Taxi and Limousine Commission (TLC) is the agency responsible
# for licensing and regulating New York City's medallion (yellow) taxis, street hail livery (green) taxis,
# for-hire vehicles (FHVs), commuter vans, and paratransit vehicles.
#
# The Taxi and Limousine Commission (TLC) regulates how much a cab can charge per mile or per minute, determines a cab company's leasing fees for drivers, monitors routes taken by the drivers (to ensure they are not artificially inflating the price), and much more. In essence, a cab company (or a cab driver) can only make as much money as the government allows them to make.
#
# The taxis in New York are operating in NYC area which divided by 5 borough:
# 1. 'Manhattan'
# 2. 'Brooklyn'
# 3. 'Queens',
# 4. 'Bronx',
# 5. 'Staten Island']
#
# **What is a Borough?**
# Boroughs (pronounced burrow) are formal subdivisions of cities that have some aspects of self-government.
#
# <img src="https://freetoursbyfoot.com/wp-content/uploads/2022/12/5-boroughs.png" width="50%" height="50%">
#
#
#
# The TLC collects trip record
# information for each taxi and for-hire vehicle trip completed by our licensed drivers and vehicles.
# We receive taxi trip data from the technology service providers (TSPs) that provide electronic
# metering in each cab, **this data will be the base of our dataset** in our analysis. [Read more](https://www.investopedia.com/articles/professionals/092515/how-nycs-yellow-cab-works-and-makes-money.asp*)
#
# ## **Stakeholder Statement**
#
# Taxi companies may be interested in understanding demand patterns, identifying popular pickup/drop-off locations, and pricing strategies to maximize revenue. They may also want to improve service quality and efficiency based on customer behavior analysis.
#
# ## **Goals Setting & Problem Statement**
#
# This project analysis generally aims to provide insights on the day-to-day operations of NYC taxi,
#
#     1. How to optimize revenues and streamlining operations?
#
#     2. How to to better serve customers by undertanding their behaviours?
#
#     3. How to optimize the distribution of drivers?

# %% [markdown]
# ## Data Understanding
# ---
# ## **Dataset: NYC TLC Taxi Trip Data**
#
# The taxi dataset used in this project is yellow taxi trip data, which records attributes such as pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts. Yellow taxis are taxis that allowed to respond to street hailed from a passenger in all five boroughs.

# %% [markdown]
# ### NYC TLC Taxi Trip Data
#
# | Columns       | Description |  Notes|
# | :---          |    :----   | :---- |
# | 'VendorID'    | LPEP provider that provided the record.|  |
# | 'lpep_pickup_datetime',   | Starting time from taxi meter
# | 'lpep_dropoff_datetime',  | Ending time from taxi meter
# | 'store_and_fwd_flag',     | Trip record are saved and send after signal received | Y= store n forwad N=Not store n forward
# | 'RatecodeID',             | The final rate code in effect at the end of the trip.   *There are different rates for different type of trips & airport destination.*|  1=Standard rate, 2=JFK (Airport rate), 3=Newark   (Newark Country), 4=Nassau or Westchester (County), 5=Negotiated fare , 6=Group ride|
# | 'PULocationID',           | Pickup location, using Taxi Zone code
# | 'DOLocationID',           | Dropoff location, using Taxi Zone code
# | 'passenger_count',        | # of passengers, driver manually input, max 6 by law
# | 'trip_distance',          | Distance per trip, in miles
# | 'fare_amount',            | The time and distance fare is calculated by the meter. includes the $0.50 and $1 rush hour and overnight charges
# | 'extra',                  | only includes the $0.50 and $1 rush hour and overnight charges.
# | 'mta_tax',                | $0.50 MTA tax that is automatically triggered based on the metered rate in use.
# | 'tip_amount',             | tips from customers, tips from customers with CC payment
# | 'tolls_amount',           | tolls fare amount
# | 'ehail_fee',              | - | unidentified, all nulls  **[TO BE DROPPED]** |
# | 'improvement_surcharge',  | $0.30 improvement surcharge assessed on hailed trips at the flag drop.
# | 'total_amount',           | The total amount charged to passengers. Does not include cash tips.
# | 'payment_type',           | 1 = Credit card 2 = Cash 3 = No charge 4 = Dispute 5 = Unknown 6 = Voided trip
# | 'trip_type',              | 1 = Street|hail (inside the city) 2 = Dispatch (outside city)
# | 'congestion_surcharge'    | surcharge for traffic congestion

# %% [markdown]
# ---

# %% [markdown]
# **ADDITIONAL Dataset: Taxi Zone Dataset**
#
# The pick-up and drop-off locations are populated by numbers ranging from 1 to 263. These numbers corresponds to taxi zone.
#
# • Taxi Zone Shapefile: contains geometric information of each taxi zones.
#
# • Taxi Zone Look Up Table: a table that contains a list of TLC taxi zone location IDs, location names, and corresponding boroughs of each zone.
#
# Obtained from: https://www.nyc.gov/assets/tlc/downloads/pdf/trip_record_user_guide.pdf

# %% [markdown]
# # 1. Data Preparation: Reading & Load Data

# %%
#Import relevant library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Set display columns to accomodate all columns
pd.options.display.max_columns = 100

# %%
#Loading Data

df = pd.read_csv('/Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/Raw Dataset/NYC TLC Trip Record.csv')
# Out:
# /var/folders/hp/56vw0j_10t7b71dy17hxntmh0000gp/T/ipykernel_45891/729993034.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/Raw Dataset/NYC TLC Trip Record.csv')

# %%
#Data preview
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2         2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3         1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4         1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143              1.0           2.58
# 1         1.0            24            43              1.0           1.81
# 2         1.0           223           179              1.0           0.00
# 3         1.0            41           238              1.0           1.30
# 4         1.0            41            74              1.0           1.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         14.9    1.0      0.5        4.03           0.0        NaN
# 1         10.7    1.0      0.5        2.64           0.0        NaN
# 2          7.2    1.0      0.5        1.94           0.0        NaN
# 3          6.5    0.5      1.5        1.70           0.0        NaN
# 4          6.0    0.5      1.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
# 1                    1.0         15.84           1.0        1.0
# 2                    1.0         11.64           1.0        1.0
# 3                    1.0         10.20           1.0        1.0
# 4                    1.0          8.00           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %%
#General info on data columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68211 entries, 0 to 68210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               68211 non-null  int64
#  1   lpep_pickup_datetime   68211 non-null  object
#  2   lpep_dropoff_datetime  68211 non-null  object
#  3   store_and_fwd_flag     63887 non-null  object
#  4   RatecodeID             63887 non-null  float64
#  5   PULocationID           68211 non-null  int64
#  6   DOLocationID           68211 non-null  int64
#  7   passenger_count        63887 non-null  float64
#  8   trip_distance          68211 non-null  float64
#  9   fare_amount            68211 non-null  float64
#  10  extra                  68211 non-null  float64
#  11  mta_tax                68211 non-null  float64
#  12  tip_amount             68211 non-null  float64
#  13  tolls_amount           68211 non-null  float64
#  14  ehail_fee              0 non-null      float64
#  15  improvement_surcharge  68211 non-null  float64
#  16  total_amount           68211 non-null  float64
#  17  payment_type           63887 non-null  float64
#  18  trip_type              63877 non-null  float64
#  19  congestion_surcharge   63887 non-null  float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 10.4+ MB

# %%
#Construct deep Info on columns & values:

NYCtaxi = []
for i in df.columns:
    NYCtaxi.append([i, df[i].dtypes,
                      df[i].isna().sum(),
                      round((((df[i].isna().sum())/(len(df)))*100),2), 
                    df[i].nunique(), 
                    df[i].sample(3).values])
pd.DataFrame(NYCtaxi, columns = ['dataFeatures', 'dataType', 'null', 'nullPct', 'unique','uniqueSample'])
# Out:
#              dataFeatures dataType   null  nullPct  unique  \
# 0                VendorID    int64      0     0.00       2
# 1    lpep_pickup_datetime   object      0     0.00   66575
# 2   lpep_dropoff_datetime   object      0     0.00   66519
# 3      store_and_fwd_flag   object   4324     6.34       2
# 4              RatecodeID  float64   4324     6.34       6
# 5            PULocationID    int64      0     0.00     226
# 6            DOLocationID    int64      0     0.00     249
# 7         passenger_count  float64   4324     6.34      10
# 8           trip_distance  float64      0     0.00    1870
# 9             fare_amount  float64      0     0.00    2553
# 10                  extra  float64      0     0.00      16
# 11                mta_tax  float64      0     0.00       6
# 12             tip_amount  float64      0     0.00    1492
# 13           tolls_amount  float64      0     0.00      26
# 14              ehail_fee  float64  68211   100.00       0
# 15  improvement_surcharge  float64      0     0.00       5
# 16           total_amount  float64      0     0.00    4670
# 17           payment_type  float64   4324     6.34       5
# 18              trip_type  float64   4334     6.35       2
# 19   congestion_surcharge  float64   4324     6.34       4
#
#                                          uniqueSample
# 0                                           [2, 2, 2]
# 1   [2023-01-03 15:21:10, 2023-01-06 23:13:01, 202...
# 2   [2023-01-31 18:16:58, 2023-01-25 17:54:08, 202...
# 3                                           [N, N, N]
# 4                                     [1.0, 1.0, 1.0]
# 5                                       [166, 74, 41]
# 6                                      [223, 79, 166]
# 7                                     [1.0, 1.0, 1.0]
# 8                                   [1.79, 3.42, 1.5]
# 9                                   [5.8, 19.1, 10.0]
# 10                                    [0.0, 0.0, 1.0]
# 11                                    [1.5, 0.0, 0.5]
# 12                                   [3.07, 0.0, 0.0]
# 13                                    [0.0, 0.0, 0.0]
# 14                                    [nan, nan, nan]
# 15                                    [1.0, 1.0, 1.0]
# 16                                 [33.2, 16.7, 37.2]
# 17                                    [2.0, 2.0, 2.0]
# 18                                    [1.0, 1.0, 1.0]
# 19                                  [0.0, 2.75, 2.75]

# %% [markdown]
# > From deep data info, we need to prepare by cleaning the data before deep diving into analysis.
# > Data in need of cleaning would be:
# > - Duplicate values
# > - Null / Missing Data
# > - Extreme Outliers & Data Anomalies

# %% [markdown]
# ---

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# **Overview**:
# - 2.1 Drop Duplicate rows
# - 2.5 Dropping Unnecessary Columns
# - 2.6 Converting columns containing time infro from Object > Datetime
#     - lpep_pickup_datetime
#     - lpep_dropoff_datetime
# - 2.2 Cleaning Null Values
#     - Substitute null values if appropriate data are available
#     - Drop null values if appropriate data not available
#     - Null values in **store_and_fwd_flag** column --> replace with Y
#     - Null values in **RatecodeID** column --> replace according to MTAtax
#     - Null values in **passenger_count** column --> replace according to mean/median of passenger
#     - Null values in **payment_type** column --> Replace with CC if tips are recorded
#     - Null values in **trip_type** column --> replace types based on trip distance / fare / PU & DU location
#     - Null values in **congestion_surcharge** --> replace with data based on location / mean/median of available values
# - 2.3 Finding & Fixing Data Anomalies
#     - Negative values on numerical columns
# - 2.4 Check distribution in numerical columns, observe & fix outliers

# %% [markdown]
# ## 2.1 Dropping Duplicate Rows

# %%
#Check for duplicates --> CLEAR

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %% [markdown]
# No duplicate rows

# %% [markdown]
# ## 2.3 Cleaning Null Values

# %% [markdown]
# ### 2.3.1 Checking Null values

# %%
#Checking the amount of missing values
df.isna().sum()
# Out:
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag        4324
# RatecodeID                4324
# PULocationID                 0
# DOLocationID                 0
# passenger_count           4324
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                68211
# improvement_surcharge        0
# total_amount                 0
# payment_type              4324
# trip_type                 4334
# congestion_surcharge      4324
# dtype: int64

# %% [markdown]
# ### Note on 'store_and_fwd_flag' Column

# %%
df[df['store_and_fwd_flag'].isna()].shape
# Out:
# (4324, 20)

# %% [markdown]
# **4324** Total missing values from the column 'store_and_fwd_flag'.

# %% [markdown]
# Assuming the missing values are from the bug within 'store_and_fwd_flag' feature, which supposed to notify the system when no signal are available to update the data, **all missing values will are assumed to be device problem** (data are stored when no signal available, then forward later)

# %%
#Missing values based on VendorID

df[df['store_and_fwd_flag'].isna()]['VendorID'].value_counts(normalize=True)
# Out:
# VendorID
# 2    0.970398
# 1    0.029602
# Name: proportion, dtype: float64

# %% [markdown]
# **97%** of the missing values are obtained from **TSP vendor 2**, which indicates that the metering devices are **less reliable**.

# %% [markdown]
# ### 2.3.2 Dropping Rows with Null Values

# %%
#Percentage of missing values
round(df.isna().sum()/len(df)*100,2)
# Out:
# VendorID                   0.00
# lpep_pickup_datetime       0.00
# lpep_dropoff_datetime      0.00
# store_and_fwd_flag         6.34
# RatecodeID                 6.34
# PULocationID               0.00
# DOLocationID               0.00
# passenger_count            6.34
# trip_distance              0.00
# fare_amount                0.00
# extra                      0.00
# mta_tax                    0.00
# tip_amount                 0.00
# tolls_amount               0.00
# ehail_fee                100.00
# improvement_surcharge      0.00
# total_amount               0.00
# payment_type               6.34
# trip_type                  6.35
# congestion_surcharge       6.34
# dtype: float64

# %% [markdown]
# The missing values are contained on **4324** rows where columns are ['RatecodeID', 'passenger_count' , 'payment_type', 'trip_type', 'congestion_surcharge'].
#
# Assuming the **6.34%** data won't have significant impact if dropped, it's decided to proceed with **dropping selected rows containing null values**.

# %%
#Dropping rows containing null values 
df.dropna(subset=['store_and_fwd_flag','RatecodeID', 'passenger_count' , 'payment_type', 'trip_type', 'congestion_surcharge'], inplace=True)

# %%
#Check remaining null values
df.isna().sum()
# Out:
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag           0
# RatecodeID                   0
# PULocationID                 0
# DOLocationID                 0
# passenger_count              0
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                63877
# improvement_surcharge        0
# total_amount                 0
# payment_type                 0
# trip_type                    0
# congestion_surcharge         0
# dtype: int64

# %% [markdown]
# ### 2.3.3 Dropping Null Column
#
# As ['ehail_fee'] columns are 100% null we will **drop the column** as it is unnecessary for our analysis.

# %%
# Drop 'ehail_fee' column

df.drop(columns='ehail_fee', inplace=True)

# %%
#Verify All null values deleted
df.isna().sum()
# Out:
# VendorID                 0
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# store_and_fwd_flag       0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# payment_type             0
# trip_type                0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# >Recap of null value cleaning:
# >- Cleaning rows from **68211** rows down to **63887**
# >- Dropped **4324** rows containing missing values on necessary columns
# >- Dropped entire column of 'ehail_fee' containing 100% missing values

# %% [markdown]
# ## 2.2 Cleaning Column Data Types

# %% [markdown]
# **Overview**
# - Convert datetime columns
# - Convert pssenger_count from float > integer

# %% [markdown]
# From the data info, we could see that there are several columns data type that needs to be adjusted:
# - Converting columns containing time infro from Object > Datetime
#     - lpep_pickup_datetime
#     - lpep_dropoff_datetime
# - Converting columns that should contain integer values
#     - passenger_count (float64 --> int64)

# %% [markdown]
# ### 2.2.1 Converting Datetime Columns

# %%
# Converting Columns df['lpep_pickup_datetime', 'lpep_dropoff_datetime'] from Object -> Datetime and catch errors if any

#Initiate blank list
error_rows = []

#return values with error and assign them to list error_rows
def convert_datetime_catch_error(date_str):
    try:
        return pd.to_datetime(date_str)
    except:
        error_rows.append(date_str)
        return date_str
    
#assign original columns with converted datetime type    
df[['lpep_pickup_datetime','lpep_dropoff_datetime']] = df[['lpep_pickup_datetime','lpep_dropoff_datetime']].apply(convert_datetime_catch_error)

# %%
#Check if there are any error rows
error_rows
# Out:
# []

# %%
#Verify datatype
df[['lpep_pickup_datetime','lpep_dropoff_datetime']].dtypes
# Out:
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# dtype: object

# %% [markdown]
# ### 2.2.2 Converting 'passenger_count' column from Float --> Integer

# %% [markdown]
# As 'passenger_count' supposed to contain the number of passenger in a taxi, it should only contain **integer values instead of float**.

# %%
#Casting df['passenger_count'] as int
df['passenger_count'] = df['passenger_count'].astype('int64')

# %%
#Verify datatype
df['passenger_count'].dtype
# Out:
# dtype('int64')

# %%
#Confirming all columns are converted appropriately
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63877 entries, 0 to 63886
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               63877 non-null  int64
#  1   lpep_pickup_datetime   63877 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  63877 non-null  datetime64[ns]
#  3   store_and_fwd_flag     63877 non-null  object
#  4   RatecodeID             63877 non-null  float64
#  5   PULocationID           63877 non-null  int64
#  6   DOLocationID           63877 non-null  int64
#  7   passenger_count        63877 non-null  int64
#  8   trip_distance          63877 non-null  float64
#  9   fare_amount            63877 non-null  float64
#  10  extra                  63877 non-null  float64
#  11  mta_tax                63877 non-null  float64
#  12  tip_amount             63877 non-null  float64
#  13  tolls_amount           63877 non-null  float64
#  14  improvement_surcharge  63877 non-null  float64
#  15  total_amount           63877 non-null  float64
#  16  payment_type           63877 non-null  float64
#  17  trip_type              63877 non-null  float64
#  18  congestion_surcharge   63877 non-null  float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# memory usage: 9.7+ MB

# %% [markdown]
# Successfully converted the columns to datetime

# %% [markdown]
# ---

# %% [markdown]
# ## 2.4 Cleaning up Data Anomalies

# %% [markdown]
# ### 2.3.1 Check for data abnormalities

# %%
#Checking for anomalies from descriptive stats
df.describe()
# Out:
#            VendorID           lpep_pickup_datetime  \
# count  63877.000000                          63877
# mean       1.855895  2023-01-16 20:29:28.932651776
# min        1.000000            2009-01-01 20:21:27
# 25%        2.000000            2023-01-09 12:15:18
# 50%        2.000000            2023-01-17 08:44:46
# 75%        2.000000            2023-01-24 16:18:41
# max        2.000000            2023-02-01 03:10:05
# std        0.351199                            NaN
#
#                lpep_dropoff_datetime    RatecodeID  PULocationID  \
# count                          63877  63877.000000  63877.000000
# mean   2023-01-16 20:47:27.346791168      1.101836     97.730200
# min              2009-01-02 11:07:31      1.000000      1.000000
# 25%              2023-01-09 12:33:17      1.000000     74.000000
# 50%              2023-01-17 08:59:19      1.000000     75.000000
# 75%              2023-01-24 16:36:36      1.000000    117.000000
# max              2023-02-01 17:27:05      5.000000    265.000000
# std                              NaN      0.620487     60.173501
#
#        DOLocationID  passenger_count  trip_distance   fare_amount  \
# count  63877.000000     63877.000000   63877.000000  63877.000000
# mean     138.308797         1.315920       2.576974     16.074491
# min        1.000000         0.000000       0.000000    -70.000000
# 25%       74.000000         1.000000       1.100000      9.000000
# 50%      138.000000         1.000000       1.800000     12.800000
# 75%      220.000000         1.000000       3.050000     19.100000
# max      265.000000         9.000000    1571.970000    490.000000
# std       76.883640         0.979123       6.760261     13.277144
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  63877.000000  63877.000000  63877.000000  63877.000000
# mean       0.880473      0.626951      2.041507      0.144182
# min       -2.500000     -0.500000    -10.500000      0.000000
# 25%        0.000000      0.500000      0.000000      0.000000
# 50%        0.000000      0.500000      1.400000      0.000000
# 75%        1.000000      0.500000      3.220000      0.000000
# max       12.500000      2.750000    222.220000     36.050000
# std        1.292861      0.366919      2.998734      1.012740
#
#        improvement_surcharge  total_amount  payment_type     trip_type  \
# count           63877.000000  63877.000000  63877.000000  63877.000000
# mean                0.949187     21.200955      1.373671      1.021933
# min                -1.000000    -71.500000      1.000000      1.000000
# 25%                 1.000000     12.600000      1.000000      1.000000
# 50%                 1.000000     17.500000      1.000000      1.000000
# 75%                 1.000000     25.500000      2.000000      1.000000
# max                 1.000000    491.000000      5.000000      2.000000
# std                 0.201782     15.131310      0.508058      0.146465
#
#        congestion_surcharge
# count          63877.000000
# mean               0.726862
# min               -2.750000
# 25%                0.000000
# 50%                0.000000
# 75%                2.750000
# max                2.750000
# std                1.212897

# %% [markdown]
# >From the stats it is found that some data have abnormal values:
# >- **Fare** datas have **negative values** where it's supposed to be positive only values
# >- Possible **outliers** on **trip distance** and **fares** data

# %% [markdown]
# ### 2.3.2 Checking rows with Fare data having negative values

# %%
df.describe()
# Out:
#            VendorID           lpep_pickup_datetime  \
# count  63877.000000                          63877
# mean       1.855895  2023-01-16 20:29:28.932651776
# min        1.000000            2009-01-01 20:21:27
# 25%        2.000000            2023-01-09 12:15:18
# 50%        2.000000            2023-01-17 08:44:46
# 75%        2.000000            2023-01-24 16:18:41
# max        2.000000            2023-02-01 03:10:05
# std        0.351199                            NaN
#
#                lpep_dropoff_datetime    RatecodeID  PULocationID  \
# count                          63877  63877.000000  63877.000000
# mean   2023-01-16 20:47:27.346791168      1.101836     97.730200
# min              2009-01-02 11:07:31      1.000000      1.000000
# 25%              2023-01-09 12:33:17      1.000000     74.000000
# 50%              2023-01-17 08:59:19      1.000000     75.000000
# 75%              2023-01-24 16:36:36      1.000000    117.000000
# max              2023-02-01 17:27:05      5.000000    265.000000
# std                              NaN      0.620487     60.173501
#
#        DOLocationID  passenger_count  trip_distance   fare_amount  \
# count  63877.000000     63877.000000   63877.000000  63877.000000
# mean     138.308797         1.315920       2.576974     16.074491
# min        1.000000         0.000000       0.000000    -70.000000
# 25%       74.000000         1.000000       1.100000      9.000000
# 50%      138.000000         1.000000       1.800000     12.800000
# 75%      220.000000         1.000000       3.050000     19.100000
# max      265.000000         9.000000    1571.970000    490.000000
# std       76.883640         0.979123       6.760261     13.277144
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  63877.000000  63877.000000  63877.000000  63877.000000
# mean       0.880473      0.626951      2.041507      0.144182
# min       -2.500000     -0.500000    -10.500000      0.000000
# 25%        0.000000      0.500000      0.000000      0.000000
# 50%        0.000000      0.500000      1.400000      0.000000
# 75%        1.000000      0.500000      3.220000      0.000000
# max       12.500000      2.750000    222.220000     36.050000
# std        1.292861      0.366919      2.998734      1.012740
#
#        improvement_surcharge  total_amount  payment_type     trip_type  \
# count           63877.000000  63877.000000  63877.000000  63877.000000
# mean                0.949187     21.200955      1.373671      1.021933
# min                -1.000000    -71.500000      1.000000      1.000000
# 25%                 1.000000     12.600000      1.000000      1.000000
# 50%                 1.000000     17.500000      1.000000      1.000000
# 75%                 1.000000     25.500000      2.000000      1.000000
# max                 1.000000    491.000000      5.000000      2.000000
# std                 0.201782     15.131310      0.508058      0.146465
#
#        congestion_surcharge
# count          63877.000000
# mean               0.726862
# min               -2.750000
# 25%                0.000000
# 50%                0.000000
# 75%                2.750000
# max                2.750000
# std                1.212897

# %% [markdown]
# **Fare** datas have **negative values** where it's supposed to be positive only values

# %%
#Check where fare contains negative values, store to a variable
negativeVal = df[df['total_amount'] < 0 ]
negativeVal
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 662           2  2023-01-01 14:58:13   2023-01-01 14:58:39                  N
# 898           2  2023-01-01 17:24:52   2023-01-01 17:25:12                  N
# 1317          2  2023-01-02 02:05:08   2023-01-02 02:12:57                  N
# 1686          2  2023-01-02 12:56:53   2023-01-02 13:00:10                  N
# 1864          2  2023-01-02 13:51:33   2023-01-02 13:52:42                  N
# ...         ...                  ...                   ...                ...
# 63358         2  2023-01-31 18:39:16   2023-01-31 18:39:29                  N
# 63544         2  2023-01-31 19:06:18   2023-01-31 19:06:46                  N
# 63655         2  2023-01-31 20:29:00   2023-01-31 20:29:14                  N
# 63807         2  2023-01-31 22:44:16   2023-01-31 22:45:18                  N
# 63868         2  2023-01-31 23:44:44   2023-01-31 23:45:15                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 662           1.0            75            74                2           0.17
# 898           1.0           193           193                1           0.00
# 1317          1.0           129            82                1           0.64
# 1686          1.0            75            75                1           0.77
# 1864          1.0            75            75                2           0.08
# ...           ...           ...           ...              ...            ...
# 63358         1.0           130           130                3           0.05
# 63544         1.0            75            75                2           0.08
# 63655         1.0            74            74                1           0.00
# 63807         1.0           256           256                1           0.15
# 63868         5.0           264           264                1           0.00
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 662           -3.0    0.0     -0.5         0.0           0.0
# 898           -3.0    0.0     -0.5         0.0           0.0
# 1317          -8.6   -1.0     -0.5         0.0           0.0
# 1686          -4.5    0.0     -0.5         0.0           0.0
# 1864          -3.7    0.0     -0.5         0.0           0.0
# ...            ...    ...      ...         ...           ...
# 63358         -3.0   -2.5     -0.5         0.0           0.0
# 63544         -3.0   -2.5     -0.5         0.0           0.0
# 63655         -2.5   -0.5     -0.5         0.0           0.0
# 63807         -3.7   -1.0     -0.5         0.0           0.0
# 63868        -10.0    0.0      0.0         0.0           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 662                     -1.0          -4.5           3.0        1.0
# 898                     -1.0          -4.5           4.0        1.0
# 1317                    -1.0         -11.1           3.0        1.0
# 1686                    -0.3          -5.3           4.0        1.0
# 1864                    -1.0          -5.2           3.0        1.0
# ...                      ...           ...           ...        ...
# 63358                   -1.0          -7.0           4.0        1.0
# 63544                   -1.0          -7.0           3.0        1.0
# 63655                   -0.3          -3.8           3.0        1.0
# 63807                   -1.0          -6.2           3.0        1.0
# 63868                   -1.0         -11.0           4.0        2.0
#
#        congestion_surcharge
# 662                     0.0
# 898                     0.0
# 1317                    0.0
# 1686                    0.0
# 1864                    0.0
# ...                     ...
# 63358                   0.0
# 63544                   0.0
# 63655                   0.0
# 63807                   0.0
# 63868                   0.0
#
# [174 rows x 19 columns]

# %%
#Checking duplicates based on [lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID'] columns
df[df.duplicated(subset=['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID'] ,keep=False)]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 662           2  2023-01-01 14:58:13   2023-01-01 14:58:39                  N
# 663           2  2023-01-01 14:58:13   2023-01-01 14:58:39                  N
# 898           2  2023-01-01 17:24:52   2023-01-01 17:25:12                  N
# 899           2  2023-01-01 17:24:52   2023-01-01 17:25:12                  N
# 1317          2  2023-01-02 02:05:08   2023-01-02 02:12:57                  N
# ...         ...                  ...                   ...                ...
# 63656         2  2023-01-31 20:29:00   2023-01-31 20:29:14                  N
# 63807         2  2023-01-31 22:44:16   2023-01-31 22:45:18                  N
# 63808         2  2023-01-31 22:44:16   2023-01-31 22:45:18                  N
# 63868         2  2023-01-31 23:44:44   2023-01-31 23:45:15                  N
# 63869         2  2023-01-31 23:44:44   2023-01-31 23:45:15                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 662           1.0            75            74                2           0.17
# 663           1.0            75            74                2           0.17
# 898           1.0           193           193                1           0.00
# 899           1.0           193           193                1           0.00
# 1317          1.0           129            82                1           0.64
# ...           ...           ...           ...              ...            ...
# 63656         1.0            74            74                1           0.00
# 63807         1.0           256           256                1           0.15
# 63808         1.0           256           256                1           0.15
# 63868         5.0           264           264                1           0.00
# 63869         5.0           264           264                1           0.00
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 662           -3.0    0.0     -0.5         0.0           0.0
# 663            3.0    0.0      0.5         0.0           0.0
# 898           -3.0    0.0     -0.5         0.0           0.0
# 899            3.0    0.0      0.5         0.0           0.0
# 1317          -8.6   -1.0     -0.5         0.0           0.0
# ...            ...    ...      ...         ...           ...
# 63656          2.5    0.5      0.5         0.0           0.0
# 63807         -3.7   -1.0     -0.5         0.0           0.0
# 63808          3.7    1.0      0.5         0.0           0.0
# 63868        -10.0    0.0      0.0         0.0           0.0
# 63869         10.0    0.0      0.0         0.0           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 662                     -1.0          -4.5           3.0        1.0
# 663                      1.0           4.5           3.0        1.0
# 898                     -1.0          -4.5           4.0        1.0
# 899                      1.0           4.5           4.0        1.0
# 1317                    -1.0         -11.1           3.0        1.0
# ...                      ...           ...           ...        ...
# 63656                    0.3           3.8           3.0        1.0
# 63807                   -1.0          -6.2           3.0        1.0
# 63808                    1.0           6.2           3.0        1.0
# 63868                   -1.0         -11.0           4.0        2.0
# 63869                    1.0          11.0           4.0        2.0
#
#        congestion_surcharge
# 662                     0.0
# 663                     0.0
# 898                     0.0
# 899                     0.0
# 1317                    0.0
# ...                     ...
# 63656                   0.0
# 63807                   0.0
# 63808                   0.0
# 63868                   0.0
# 63869                   0.0
#
# [348 rows x 19 columns]

# %% [markdown]
# The negative values turns out are the **duplicate** data base on [lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID'] columns, but negative values on the fare datas.

# %%
# Dropping the rows based on index containing negative fare values 
df.drop(negativeVal.index, inplace=True)

# %%
#Verify on negative fares
df[df['total_amount'] < 0]
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %% [markdown]
# >Cleared **174 rows** containing negative value of total_amount

# %% [markdown]
# ### 2.3.3 Checking 'passenger_count' having <1 or >7 values

# %% [markdown]
# Verify the number of passenger based on common logic
# - Passenger should be >= 1 for a taxi to be taking trip
# - Passenger should be <= 7 as stated by the TLC regulation (source: https://www.nyc.gov/site/tlc/passengers/passenger-frequently-asked-questions.page)

# %%
#Check the data based on passenger_count < 1
df[df['passenger_count'] < 1]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 99            2  2023-01-01 01:27:36   2023-01-01 01:27:43                  N
# 254           1  2023-01-01 04:21:35   2023-01-01 04:30:00                  N
# 446           1  2023-01-01 11:42:13   2023-01-01 11:49:21                  N
# 486           1  2023-01-01 12:11:05   2023-01-01 12:20:45                  N
# 487           1  2023-01-01 12:56:11   2023-01-01 13:01:06                  N
# ...         ...                  ...                   ...                ...
# 63239         1  2023-01-31 18:27:02   2023-01-31 18:27:08                  N
# 63247         1  2023-01-31 18:01:21   2023-01-31 18:09:22                  N
# 63288         1  2023-01-31 18:07:39   2023-01-31 18:07:55                  N
# 63420         1  2023-01-31 18:32:09   2023-01-31 18:32:33                  N
# 63421         1  2023-01-31 18:36:10   2023-01-31 18:36:48                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 99            5.0           168           168                0            0.0
# 254           1.0           129           129                0            1.3
# 446           1.0           260           260                0            1.2
# 486           1.0            42           127                0            3.4
# 487           1.0            75           236                0            1.2
# ...           ...           ...           ...              ...            ...
# 63239         1.0           145           145                0            0.0
# 63247         1.0           236           236                0            1.0
# 63288         1.0           260           260                0            0.1
# 63420         1.0           145           145                0            0.0
# 63421         1.0           145           145                0            0.0
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 99            20.0   0.00      0.0         0.0           0.0
# 254            8.0   0.50      1.5         2.8           4.0
# 446            8.6   0.00      1.5         2.0           0.0
# 486           16.3   0.00      1.5         1.0           0.0
# 487            7.2   2.75      1.5         3.4           0.0
# ...            ...    ...      ...         ...           ...
# 63239          3.0   2.50      1.5         0.0           0.0
# 63247          9.3   5.25      1.5         3.2           0.0
# 63288          3.0   2.50      1.5         0.0           0.0
# 63420          3.0   2.50      1.5         0.0           0.0
# 63421          3.0   2.50      1.5         0.0           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 99                       1.0         21.00           1.0        2.0
# 254                      1.0         16.80           1.0        1.0
# 446                      1.0         12.10           1.0        1.0
# 486                      1.0         18.80           1.0        1.0
# 487                      1.0         14.85           1.0        1.0
# ...                      ...           ...           ...        ...
# 63239                    1.0          7.00           2.0        1.0
# 63247                    1.0         19.25           1.0        1.0
# 63288                    1.0          7.00           2.0        1.0
# 63420                    1.0          7.00           3.0        1.0
# 63421                    1.0          7.00           3.0        1.0
#
#        congestion_surcharge
# 99                     0.00
# 254                    0.00
# 446                    0.00
# 486                    0.00
# 487                    2.75
# ...                     ...
# 63239                  0.00
# 63247                  2.75
# 63288                  0.00
# 63420                  0.00
# 63421                  0.00
#
# [336 rows x 19 columns]

# %%
#Check the data based on passenger_count > 7
df[df['passenger_count'] > 7]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 11478         2  2023-01-06 21:10:08   2023-01-06 21:10:11                  N
# 26612         2  2023-01-14 03:09:48   2023-01-14 03:09:50                  N
# 29824         2  2023-01-15 19:21:14   2023-01-15 19:21:17                  N
# 44307         2  2023-01-22 23:40:13   2023-01-22 23:40:21                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 11478         5.0           265           265                9           0.00
# 26612         5.0            95            95                8           0.12
# 29824         5.0            75            75                8           0.00
# 44307         5.0            83            83                9           0.00
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 11478        90.00    0.0      0.0         6.0           0.0
# 26612         8.90    0.0      0.0         5.0           0.0
# 29824         8.00    0.0      0.0         1.0           0.0
# 44307         9.99    0.0      0.0         2.2           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 11478                    0.3         96.30           1.0        2.0
# 26612                    1.0         14.90           1.0        2.0
# 29824                    1.0         10.00           1.0        2.0
# 44307                    1.0         13.19           1.0        2.0
#
#        congestion_surcharge
# 11478                   0.0
# 26612                   0.0
# 29824                   0.0
# 44307                   0.0

# %% [markdown]
# > - 336 data contains <1 passenger
# > - 4 data contains >7 passenger
#
# > We will take a deeper look on data analysis

# %% [markdown]
# ### 2.3.4 Checking on year datetime

# %%
#Check data from years datetime
df['lpep_pickup_datetime'].dt.year.value_counts()
# Out:
# lpep_pickup_datetime
# 2023    63700
# 2022        2
# 2009        1
# Name: count, dtype: int64

# %% [markdown]
# Only 3 datas outside year 2023, as it's insignificant and assumed won't provide any insight, those rows will be dropped

# %%
#Dropping rows with year date outside 2023 

display(df[df['lpep_pickup_datetime'].dt.year < 2023])
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 298           2  2022-12-09 14:10:49   2022-12-09 14:22:26                  N
# 318           2  2022-12-09 14:55:42   2022-12-09 15:33:06                  N
# 17874         2  2009-01-01 20:21:27   2009-01-02 11:07:31                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 298           1.0             7            56                1           5.37
# 318           1.0           260           164                1           5.48
# 17874         1.0            65           178                1           7.72
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 298           16.0    0.0      0.5         0.0          0.00
# 318           25.5    0.0      0.5         0.0          6.55
# 17874         34.5    0.0      0.5         7.2          0.00
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 298                      0.3          16.8           2.0        1.0
# 318                      0.3          35.6           2.0        1.0
# 17874                    1.0          43.2           1.0        1.0
#
#        congestion_surcharge
# 298                    0.00
# 318                    2.75
# 17874                  0.00

# %%
#find index where data outside 2023 located
yearNotIncluded = df[df['lpep_pickup_datetime'].dt.year < 2023].index

# %%
df.drop(index=yearNotIncluded, inplace=True)

# %% [markdown]
# > **Recap on Data Anomaly Findings**
# > - Cleared **174 rows** containing negative value of trip fares
# > - **336** data contains <1 passenger
# > - **4** data contains >7 passenger
# > - **3** data are outside year 2023

# %% [markdown]
# ## 2.4 Analyze Outliers

# %% [markdown]
# ### 2.4.1 Initial analysis from descriptive stats

# %%
df.describe()
# Out:
#            VendorID           lpep_pickup_datetime  \
# count  63700.000000                          63700
# mean       1.855495  2023-01-16 22:33:29.431522560
# min        1.000000            2023-01-01 00:01:31
# 25%        2.000000     2023-01-09 12:32:05.500000
# 50%        2.000000     2023-01-17 08:47:56.500000
# 75%        2.000000  2023-01-24 16:18:41.750000128
# max        2.000000            2023-02-01 03:10:05
# std        0.351604                            NaN
#
#                lpep_dropoff_datetime    RatecodeID  PULocationID  \
# count                          63700  63700.000000  63700.000000
# mean   2023-01-16 22:51:29.574615296      1.101523     97.691397
# min              2023-01-01 00:13:26      1.000000      1.000000
# 25%              2023-01-09 12:44:37      1.000000     74.000000
# 50%              2023-01-17 09:03:58      1.000000     75.000000
# 75%    2023-01-24 16:36:40.750000128      1.000000    116.000000
# max              2023-02-01 17:27:05      5.000000    265.000000
# std                              NaN      0.619576     60.141650
#
#        DOLocationID  passenger_count  trip_distance   fare_amount  \
# count  63700.000000     63700.000000   63700.000000  63700.000000
# mean     138.374992         1.315604       2.582926     16.134628
# min        1.000000         0.000000       0.000000      0.000000
# 25%       74.000000         1.000000       1.100000      9.300000
# 50%      138.000000         1.000000       1.800000     12.800000
# 75%      222.000000         1.000000       3.060000     19.100000
# max      265.000000         9.000000    1571.970000    490.000000
# std       76.884531         0.979364       6.767900     13.234022
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  63700.000000  63700.000000  63700.000000   63700.00000
# mean       0.885267      0.629965      2.047305       0.14448
# min        0.000000      0.000000      0.000000       0.00000
# 25%        0.000000      0.500000      0.000000       0.00000
# 50%        0.000000      0.500000      1.460000       0.00000
# 75%        1.000000      0.500000      3.220000       0.00000
# max       12.500000      2.750000    222.220000      36.05000
# std        1.290239      0.362834      3.000444       1.01380
#
#        improvement_surcharge  total_amount  payment_type     trip_type  \
# count           63700.000000  63700.000000  63700.000000  63700.000000
# mean                0.954443     21.281682      1.368760      1.021868
# min                 0.000000      0.000000      1.000000      1.000000
# 25%                 1.000000     12.600000      1.000000      1.000000
# 50%                 1.000000     17.500000      1.000000      1.000000
# 75%                 1.000000     25.500000      2.000000      1.000000
# max                 1.000000    491.000000      5.000000      2.000000
# std                 0.175189     15.062803      0.499546      0.146254
#
#        congestion_surcharge
# count          63700.000000
# mean               0.728968
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                2.750000
# max                2.750000
# std                1.213727

# %% [markdown]
# From the initial descriptive stats, it's likely there are outlier that are heavily skewing the data on trip_distance

# %%
df.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
numerical_cols = ['passenger_count', 'trip_distance', 'fare_amount', 'extra',
       'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount']

# %%
#create a list of numerical columns
numerical_cols = ['passenger_count', 'trip_distance', 'fare_amount', 'extra',
       'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount']
#Plotting boxplot for numerical values 
plt.figure(figsize=(15, 15))
for i, column in enumerate(numerical_cols, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(data=df[column], orient='horizontal')
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4.2 Check on trip_distance

# %%
#Check trip_distance distribution by boxplot 
df['trip_distance'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# From the boxplot, we can see that there's **1 extreme outlier** which values are way up to about 1600 miles.

# %%
#Finding the extreme outlier
df[df['trip_distance'] > 200]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 33373         2  2023-01-17 18:40:38   2023-01-17 19:04:45                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 33373         5.0            82           236                1        1571.97
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 33373        29.97    0.0      0.0        3.04          6.55
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 33373                    1.0         43.31           1.0        1.0
#
#        congestion_surcharge
# 33373                  2.75

# %% [markdown]
# Zooming in further we can see the duration between pickup and drop-off are approximately **25 mins** which is **impossible** for a taxi to cover **1571 miles** within that duration. So we would **drop** the data as it is **invalid & unreasonable**.

# %%
#Finding the index & dropping the row with outlier
indexTripDistOutlier = df[df['trip_distance'] > 200].index
df.drop(indexTripDistOutlier, inplace=True)

# %%
#Check trip_distance distribution by boxplot after removing extreme outlier
df['trip_distance'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# After the **extreme outlier are removed**, the distributions are more likely to be **valid**.

# %%
df['tip_amount'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['tip_amount'] > 200]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 50588         2  2023-01-25 18:24:30   2023-01-25 18:28:48                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 50588         1.0           223           223                1           0.76
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 50588          6.5    2.5      0.5      222.22           0.0
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 50588                    1.0        232.72           1.0        1.0
#
#        congestion_surcharge
# 50588                   0.0

# %% [markdown]
# ## 2.4. Reset Indexing

# %%
#Resetting index on df
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ---

# %% [markdown]
# # 3. Additional Columns:
# To better understand and allowing us to provide deeper context on the data, we will be adding additional columns to original dataframe
# - Adding Location column referring to taxi zone code table
# - Calculate the duration of each trip using the difference between pickup and drop-off time.
# - Identify the month, day of the week, and hour for each trip. Then classify whether the trip is in workday, weekend, or, holiday.
# - Calculate the tip percentage using total amount and tip amount.

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2         2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3         1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4         1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143                1           2.58
# 1         1.0            24            43                1           1.81
# 2         1.0           223           179                1           0.00
# 3         1.0            41           238                1           1.30
# 4         1.0            41            74                1           1.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         14.9    1.0      0.5        4.03           0.0
# 1         10.7    1.0      0.5        2.64           0.0
# 2          7.2    1.0      0.5        1.94           0.0
# 3          6.5    0.5      1.5        1.70           0.0
# 4          6.0    0.5      1.5        0.00           0.0
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
# 1                    1.0         15.84           1.0        1.0
# 2                    1.0         11.64           1.0        1.0
# 3                    1.0         10.20           1.0        1.0
# 4                    1.0          8.00           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %% [markdown]
# ## 3.x Merge Zoning Code Lookup

# %% [markdown]
# **Adding ADDITIONAL Dataset: Taxi Zone Dataset**
#
# The pick-up and drop-off locations are populated by numbers ranging from 1 to 263. These numbers corresponds to taxi zone.
#
# • Taxi Zone Look Up Table: a table that contains a list of TLC taxi zone location IDs, location names, and corresponding boroughs of each zone.
#
# Obtained from: https://www.nyc.gov/assets/tlc/downloads/pdf/trip_record_user_guide.pdf

# %%
#loading taxi zone lookup table

dfZoneTable = pd.read_csv('/Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/Raw Dataset/taxi_zone_lookup.csv')
dfZoneTable
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
#Join 'PickUpLocation' 
df = df.merge(dfZoneTable[['Borough', 'Zone']], left_on=df['PULocationID'], right_on=dfZoneTable['LocationID'], how='inner')


#Renaming PickUp Zone Columns
df.rename(columns={'Borough':'PU_borough', 'Zone':'PU_zone'}, inplace=True)

#Rearange columns so new zone column are next to PULocationID
df = df[['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
       'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'PU_borough', 'PU_zone', 'DOLocationID',
       'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
       'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
       'payment_type', 'trip_type', 'congestion_surcharge']]

# %%
#Join 'DropOffLocation' 
df = df.merge(dfZoneTable[['Borough', 'Zone']], left_on=df['DOLocationID'], right_on=dfZoneTable['LocationID'], how='inner')


#Renaming PickUp Zone Columns
df.rename(columns={'Borough':'DO_borough', 'Zone':'DO_zone'}, inplace=True)

#Rearange columns so new zone column are next to DOLocationID
df = df[['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
       'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'PU_borough', 'PU_zone', 'DOLocationID','DO_borough', 'DO_zone',
       'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
       'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
       'payment_type', 'trip_type', 'congestion_surcharge']]

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-02 18:56:58   2023-01-02 19:14:50                  N
# 2         2  2023-01-03 15:28:11   2023-01-03 15:47:47                  N
# 3         2  2023-01-03 17:37:14   2023-01-03 17:51:35                  N
# 4         1  2023-01-03 19:03:53   2023-01-03 19:17:50                  N
#
#    RatecodeID  PULocationID PU_borough              PU_zone  DOLocationID  \
# 0         1.0           166  Manhattan  Morningside Heights           143
# 1         1.0           166  Manhattan  Morningside Heights           143
# 2         1.0           166  Manhattan  Morningside Heights           143
# 3         1.0           166  Manhattan  Morningside Heights           143
# 4         1.0           166  Manhattan  Morningside Heights           143
#
#   DO_borough              DO_zone  passenger_count  trip_distance  \
# 0  Manhattan  Lincoln Square West                1           2.58
# 1  Manhattan  Lincoln Square West                1           3.16
# 2  Manhattan  Lincoln Square West                1           2.55
# 3  Manhattan  Lincoln Square West                1           1.96
# 4  Manhattan  Lincoln Square West                2           2.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         14.9   1.00      0.5        4.03           0.0
# 1         19.8   0.00      0.5        0.00           0.0
# 2         19.1   0.00      0.5        4.67           0.0
# 3         15.6   2.50      0.5        0.00           0.0
# 4         13.5   5.25      1.5        0.00           0.0
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
# 1                    1.0         24.05           2.0        1.0
# 2                    1.0         28.02           1.0        1.0
# 3                    1.0         22.35           2.0        1.0
# 4                    1.0         20.25           2.0        1.0
#
#    congestion_surcharge
# 0                  2.75
# 1                  2.75
# 2                  2.75
# 3                  2.75
# 4                  2.75

# %% [markdown]
# ## 3.1 Adding Duration Column

# %%
#Duration obtained by substracting lpep_dropoff_datetime - lpep_pickup_datetime
df['trip_duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
df['trip_duration']
# Out:
# 0       0 days 00:11:01
# 1       0 days 00:17:52
# 2       0 days 00:19:36
# 3       0 days 00:14:21
# 4       0 days 00:13:57
#               ...
# 63694   0 days 00:08:48
# 63695   0 days 00:04:44
# 63696   0 days 00:20:07
# 63697   0 days 00:22:19
# 63698   0 days 00:17:56
# Name: trip_duration, Length: 63699, dtype: timedelta64[ns]

# %% [markdown]
# ## 3.2 Adding Day Name Columns

# %%
#Adding Day Name Columns
# df['day_of_week'] = df['lpep_pickup_datetime'].dt.day_name()

df['pickup_day']=df['lpep_pickup_datetime'].dt.day_name()
df['dropoff_day']=df['lpep_dropoff_datetime'].dt.day_name()
df['pickup_day_no']=df['lpep_pickup_datetime'].dt.weekday
df['dropoff_day_no']=df['lpep_dropoff_datetime'].dt.weekday
df['pickup_hour']=df['lpep_pickup_datetime'].dt.hour
df['dropoff_hour']=df['lpep_dropoff_datetime'].dt.hour
df['pickup_month']=df['lpep_pickup_datetime'].dt.month
df['dropoff_month']=df['lpep_dropoff_datetime'].dt.month

# %% [markdown]
# ## 3.2 Adding Time of Day Column

# %%
#Adding Time of Day

# %% [markdown]
# ## 3.3 Adding Tips Percentage Column

# %%
#Adding Tips percentage

df['tips_pct'] = round(df['tip_amount']/df['total_amount']*100,2)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-02 18:56:58   2023-01-02 19:14:50                  N
# 2         2  2023-01-03 15:28:11   2023-01-03 15:47:47                  N
# 3         2  2023-01-03 17:37:14   2023-01-03 17:51:35                  N
# 4         1  2023-01-03 19:03:53   2023-01-03 19:17:50                  N
#
#    RatecodeID  PULocationID PU_borough              PU_zone  DOLocationID  \
# 0         1.0           166  Manhattan  Morningside Heights           143
# 1         1.0           166  Manhattan  Morningside Heights           143
# 2         1.0           166  Manhattan  Morningside Heights           143
# 3         1.0           166  Manhattan  Morningside Heights           143
# 4         1.0           166  Manhattan  Morningside Heights           143
#
#   DO_borough              DO_zone  passenger_count  trip_distance  \
# 0  Manhattan  Lincoln Square West                1           2.58
# 1  Manhattan  Lincoln Square West                1           3.16
# 2  Manhattan  Lincoln Square West                1           2.55
# 3  Manhattan  Lincoln Square West                1           1.96
# 4  Manhattan  Lincoln Square West                2           2.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         14.9   1.00      0.5        4.03           0.0
# 1         19.8   0.00      0.5        0.00           0.0
# 2         19.1   0.00      0.5        4.67           0.0
# 3         15.6   2.50      0.5        0.00           0.0
# 4         13.5   5.25      1.5        0.00           0.0
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
# 1                    1.0         24.05           2.0        1.0
# 2                    1.0         28.02           1.0        1.0
# 3                    1.0         22.35           2.0        1.0
# 4                    1.0         20.25           2.0        1.0
#
#    congestion_surcharge   trip_duration pickup_day dropoff_day  pickup_day_no  \
# 0                  2.75 0 days 00:11:01     Sunday      Sunday              6
# 1                  2.75 0 days 00:17:52     Monday      Monday              0
# 2                  2.75 0 days 00:19:36    Tuesday     Tuesday              1
# 3                  2.75 0 days 00:14:21    Tuesday     Tuesday              1
# 4                  2.75 0 days 00:13:57    Tuesday     Tuesday              1
#
#    dropoff_day_no  pickup_hour  dropoff_hour  pickup_month  dropoff_month  \
# 0               6            0             0             1              1
# 1               0           18            19             1              1
# 2               1           15            15             1              1
# 3               1           17            17             1              1
# 4               1           19            19             1              1
#
#    tips_pct
# 0     16.67
# 1      0.00
# 2     16.67
# 3      0.00
# 4      0.00

# %% [markdown]
# ---

# %% [markdown]
# # 4. Data Analysis

# %% [markdown]
# General Insight Questions:
# 1. How many trips are taken during between a time period?
#     - What days are the busiest
#     - What hours are busiest?
# 2. How are people using a taxi service? (Passengers behaviour) ?
#     - What payment types are people using?
#     - Are people travelling solo or in groups?
#     - Average tips & tips percentage on fare
# 3. How are the taxi service operating based on areas?
#     - Which area are busiest?
#     - Which area results in more revenues?

# %% [markdown]
# ## 4.1 Trips taken between a time period

# %%
#Available time period from data
df[['lpep_dropoff_datetime', 'lpep_pickup_datetime']].agg(['max', 'min'])
# Out:
#     lpep_dropoff_datetime lpep_pickup_datetime
# max   2023-02-01 17:27:05  2023-02-01 03:10:05
# min   2023-01-01 00:13:26  2023-01-01 00:01:31

# %% [markdown]
# The Data available are within 1 month period of **January 1st 2023 - February 2nd 2023**

# %% [markdown]
# ### 4.1.1 Number of Trips Over Date

# %%
#Plotting barplot for Number of trips over date
plt.figure(figsize=(10,5))
sns.countplot(data=df, x=df['lpep_dropoff_datetime'].dt.date,  palette=['#2596be'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Plot of number of trips over date with lineplot!

# %% [markdown]
# From the number of trips over day, we can see that the total trips made are **fluctuating weekly**.

# %% [markdown]
# ### 4.1.2 Number of Trips Over Day

# %%
#Plot bar plot of trip count over day_name
pickup_day_barplot = sns.countplot(data=df, x=df['pickup_day'])
#Adding value labels on each bar
for i in pickup_day_barplot.containers:
    pickup_day_barplot.bar_label(i,)
    
#Rotate xticks 45

# %% [markdown]
# Taxi trips are **peaked on Tuesdays** and distributed almost evenly on other **weekdays**, and also **lower on weekends**.
#
# It's understandable that people are comuting less on weekends and use taxi for commuting to work.

# %%
#Total revenues over Days
df.groupby(df['pickup_day_no'])['total_amount'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='pickup_day_no'>

# %%
# !!!
#Use lineplot for pickup hour trips

# %% [markdown]
# Sunday=6
# Monday=0

# %% [markdown]
# ### Trip Counts over Hours

# %%
sns.countplot(data=df, x=df['pickup_hour'], palette=['#2596be'] )
# Out:
# <Axes: xlabel='pickup_hour', ylabel='count'>

# %% [markdown]
# The number of trips are peaked between **3PM - 6 PM**, it could be assumed that people are using taxi for commuting from office to home.

# %% [markdown]
# > It can be the base of recommendation for taxi companies to dispatch **higher number of taxis during peak hours (3PM-6PM)**.

# %% [markdown]
# ## 4.2 Passengers Behaviour

# %% [markdown]
# In general we wold like to see how passengers are using taxi services. From the data available, we can take a deeper look on:
#  - Trip count over number of passengers
#  - Preferred payment options used
#  - Tip Amount

# %% [markdown]
# ### 4.2.1 Trip Count over Number of Passengers

# %%
#Plotting barplot for each number of passengers
pcount_plot = sns.countplot(data=df, x=df['passenger_count'])
#Adding value labels on each bar
for i in pcount_plot.containers:
    pcount_plot.bar_label(i,)

# %% [markdown]
# From the chart above we can see that taxi passengers prefer to travel solo.

# %% [markdown]
#  ***Notes on Passenger Count***

# %% [markdown]
# There are 336 trips where passenger counts are 0, there are several assumptions that could be made:
# - Trips are cancelled by passenger / driver
# - People are using taxi as item delivery
# - Unrecorded data by LPEP system (error by system)
# - Human error as the number of passengers are inputted manually by the driver

# %% [markdown]
# ### 4.2.1 By Payment Type

# %%
#Plotting bar chart of trip count by payment type
payment_type_barplot = df['payment_type'].value_counts().plot(kind='barh')

for i in payment_type_barplot.containers:
    payment_type_barplot.bar_label(i,)

# %% [markdown]
# | code | 'payment_type'
# |---|---|
# | 1 | Credit card
# 2 | Cash
# 3 | No charge
# 4 | Dispute
# 5 | Unknown
# 6 | Voided trip

# %% [markdown]
# **Credit card** are most preferred payment options when using taxi services.
#
# > It could be recommended that taxi companies could leverage this by partnering with credit card companies, and come up with promotion program such as "taxi miles" to reward their customers for using taxi services.
#
# *Further analysis and data could be done if there are information about Credit Card banks in used*

# %%
#Plotting pie chart of payment types
df[df['payment_type'] < 3]['payment_type'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#Payment Type over borough
df.groupby(df['PU_borough'])['payment_type'].value_counts()

#Plotting bar chart of trip count by payment type and borough
payment_type_barplot = df.groupby(df['PU_borough'])['payment_type'].value_counts().unstack().plot(kind='bar', stacked=True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 4.3 Taxi Operations by Areas

# %%
#Create Bar plot for trip Count over Borough
tripcount_borough_barplot = df['DO_borough'].value_counts().plot(kind='bar')

plt.xlabel("Borough")
plt.ylabel("Cumulative trip counts")
plt.title("Sum of Trip Count by Borough")
plt.xticks(rotation=45)
#Total 
for i in tripcount_borough_barplot.containers:
    tripcount_borough_barplot.bar_label(i,)

# Get the patches and color the tallest
patch_h = [patch.get_height() for patch in tripcount_borough_barplot.patches]   
idx_tallest = np.argmax(patch_h)   
tripcount_borough_barplot.patches[idx_tallest].set_facecolor('orange')

# %%
df['DO_borough'].value_counts()
# Out:
# DO_borough
# Manhattan        37304
# Queens           16756
# Brooklyn          6926
# Bronx             2034
# Unknown            642
# EWR                 21
# Staten Island       16
# Name: count, dtype: int64

# %%
df['PU_borough'].value_counts()
# Out:
# PU_borough
# Manhattan        37403
# Queens           17180
# Brooklyn          7994
# Bronx              911
# Unknown            198
# Staten Island       12
# EWR                  1
# Name: count, dtype: int64

# %%
#trip count over pickup borough
df['PU_borough'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='PU_borough'>

# %%
#trip count over dropoff borough
df['DO_borough'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='DO_borough'>

# %%
#Create Bar plot for trip Count over Borough
tripcount_borough_barplot = df['PU_borough'].value_counts().plot(kind='bar')

plt.xlabel("Borough")
plt.ylabel("Cumulative trip counts")
plt.title("Sum of Trip Count by Borough")
plt.xticks(rotation=45)
#Total 
for i in tripcount_borough_barplot.containers:
    tripcount_borough_barplot.bar_label(i,)

# Get the patches and color the tallest
patch_h = [patch.get_height() for patch in tripcount_borough_barplot.patches]   
idx_tallest = np.argmax(patch_h)   
tripcount_borough_barplot.patches[idx_tallest].set_facecolor('orange')

# %%
#Create Bar plot for trip Count over Borough
tripcount_borough_barplot = df['DO_borough'].value_counts().plot(kind='bar')

plt.xlabel("Borough")
plt.ylabel("Cumulative trip counts")
plt.title("Sum of Trip Count by Borough")
plt.xticks(rotation=45)
#Total 
for i in tripcount_borough_barplot.containers:
    tripcount_borough_barplot.bar_label(i,)

# Get the patches and color the tallest, else color with grey
patch_h = [patch.get_height() for patch in tripcount_borough_barplot.patches]   
idx_tallest = np.argmax(patch_h)   

    
for patch in tripcount_borough_barplot.patches:
    patch_h

    tripcount_borough_barplot.patches[idx_tallest].set_facecolor('orange')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/V1-EDA-NYCTaxi.ipynb Cell 151 line 1
# ----> <a href='vscode-notebook-cell:/Users/Dwika/My%20Projects/Modul%202%20Purwadhika/_CAPSTONE%20Project%20Modul%202/V1-EDA-NYCTaxi.ipynb#Y344sZmlsZQ%3D%3D?line=0'>1</a> patch_h.get_height()
#
# AttributeError: 'list' object has no attribute 'get_height'

# %% [markdown]
# Most pickup of taxi trips are done within **Manhattan** Borough.
#
# It's understandable as Manhattan are considered to be the 'heart of NYC', it's geographically smallest and **most densely populated borough**; is the symbol of New York City, as home to most of the city's skyscrapers and prominent landmarks, including Times Square and Central Park. *(Source: Wikipedia)*

# %% [markdown]
# For added context, here's the general information on NYC boroughs:

# %% [markdown]
# <img src="/Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/NYC Borough.png" width="50%" height="50%">

# %%
#Total revenues over Boroughs
#sort by total amount
# df.groupby(df['PU_borough'])['total_amount'].sum().sort_values(ascending=False).plot(kind='bar')
PU_borough_barplot =  df.groupby(df['PU_borough'])['total_amount'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xticks(rotation=45)
plt.xlabel("Sum amount of Revenue ($)")
plt.ylabel("Borough")
plt.title("Sum of Revenues by Borough")
#Total 
for i in PU_borough_barplot.containers:
    PU_borough_barplot.bar_label(i,)

# Get the patches and color the tallest
patch_h = [patch.get_height() for patch in PU_borough_barplot.patches]   
idx_tallest = np.argmax(patch_h)   
PU_borough_barplot.patches[idx_tallest].set_facecolor('orange') 
#Color other patches with light grey

plt.show()

# %%
#Descriptive stats of total fares in PickUp Borough
df.groupby(df['PU_borough'])['total_amount'].agg(['median','min','max'])
# Out:
#                median    min     max
# PU_borough
# Bronx           19.00    0.0   97.28
# Brooklyn        20.88    0.0  426.00
# EWR            200.00  200.0  200.00
# Manhattan       17.10    0.0  201.00
# Queens          17.00    0.0  491.00
# Staten Island   29.50   11.2  110.25
# Unknown         21.25    0.0  355.20

# %% [markdown]
# Manhattan are generating the highest sum revenue of **$752,475** in a period of January 2023 with an average total trip fare of **$17,10** .

# %%
#Plot Map of Manhattan
tlcMap[tlcMap['borough'] == 'Manhattan'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/V1-EDA-NYCTaxi.ipynb Cell 157 line 2
#       <a href='vscode-notebook-cell:/Users/Dwika/My%20Projects/Modul%202%20Purwadhika/_CAPSTONE%20Project%20Modul%202/V1-EDA-NYCTaxi.ipynb#Y305sZmlsZQ%3D%3D?line=0'>1</a> #Plot Map of Manhattan
# ----> <a href='vscode-notebook-cell:/Users/Dwika/My%20Projects/Modul%202%20Purwadhika/_CAPSTONE%20Project%20Modul%202/V1-EDA-NYCTaxi.ipynb#Y305sZmlsZQ%3D%3D?line=1'>2</a> tlcMap[tlcMap['borough'] == 'Manhattan'].plot()
#
# NameError: name 'tlcMap' is not defined

# %%
gpd.read_file('/Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/Raw Dataset/geo_export_421a6cfb-b228-4bc0-8571-0ab6d41807ad.csv')
# Out:
#                      X                 Y        borough location_i objectid  \
# 0    -74.1767785471836  40.6895151478039            EWR          1        1
# 1     -73.826141187548  40.6257250653606         Queens          2        2
# 2    -73.8494797117996  40.8658720486048          Bronx          3        3
# 3    -73.9770238531481  40.7241508237094      Manhattan          4        4
# 4    -74.1899382186973  40.5503388087419  Staten Island          5        5
# ..                 ...               ...            ...        ...      ...
# 258  -73.9591084943837  40.7109802819405       Brooklyn        256      256
# 259  -73.8563997211766  40.8990800823679          Bronx        259      259
# 260  -73.9037149992412  40.7467908284139         Queens        260      260
# 261  -74.0129195637957  40.7089752027539      Manhattan        261      261
# 262  -73.9458299213996  40.7765365407327      Manhattan        262      262
#
#             shape_area       shape_leng                       zone geometry
# 0      0.0007823067885   0.116357453189             Newark Airport     None
# 1     0.00486634037837    0.43346966679                Jamaica Bay     None
# 2    0.000314414156821  0.0843411059012    Allerton/Pelham Gardens     None
# 3    0.000111871946192  0.0435665270921              Alphabet City     None
# 4    0.000497957489363  0.0921464898574              Arden Heights     None
# ..                 ...              ...                        ...      ...
# 258  0.000168611097013  0.0679149669603  Williamsburg (South Side)     None
# 259  0.000394552487366   0.126750305191         Woodlawn/Wakefield     None
# 260  0.000422345326907   0.133514154636                   Woodside     None
# 261  3.43423231652e-05  0.0271204563616         World Trade Center     None
# 262  0.000122330270966  0.0490636231541             Yorkville East     None
#
# [263 rows x 9 columns]

# %%
df[df['PU_borough'] == 'Manhattan']['PU_zone'].value_counts(ascending=True).tail(10).plot(kind='barh')
# Out:
# <Axes: ylabel='PU_zone'>

# %%
df[df['PU_borough'] == 'Manhattan']['DO_zone'].value_counts(ascending=True).tail(10).plot(kind='barh')
# Out:
# <Axes: ylabel='DO_zone'>

# %%
# Create a cross-tabulation between Pickup Location (PULocationID) and Dropoff Location (DOLocationID)
cross_tab = pd.crosstab(df['PU_borough'], df['DO_borough'])

# Optionally, you can add margins to get row and column totals
cross_tab_with_totals = pd.crosstab(df['PU_borough'], df['DO_borough'], margins=True, margins_name='Total')

cross_tab_with_totals
# Out:
# DO_borough     Bronx  Brooklyn  EWR  Manhattan  Queens  Staten Island  \
# PU_borough
# Bronx            608        16    0        223      34              0
# Brooklyn          36      6184    7       1325     342              2
# EWR                0         0    0          0       0              0
# Manhattan       1349       230    7      34928     767              3
# Queens            40       471    6        827   15596              1
# Staten Island      0         2    0          0       1              9
# Unknown            1        23    1          1      16              1
# Total           2034      6926   21      37304   16756             16
#
# DO_borough     Unknown  Total
# PU_borough
# Bronx               30    911
# Brooklyn            98   7994
# EWR                  1      1
# Manhattan          119  37403
# Queens             239  17180
# Staten Island        0     12
# Unknown            155    198
# Total              642  63699

# %%
sns.heatmap(data=cross_tab, cmap='RdPu')
# Out:
# <Axes: xlabel='DO_borough', ylabel='PU_borough'>

# %% [markdown]
# # 4.x Geographical Views

# %%
import geopandas as gpd

# %%
tlcMap = gpd.read_file('/Users/Dwika/My Projects/Modul 2 Purwadhika/_CAPSTONE Project Modul 2/Raw Dataset/NYC Taxi Zones/geo_export_421a6cfb-b228-4bc0-8571-0ab6d41807ad.shp')

# %%
#Plotting NYC Map Plot from shapefile
tlcMap.plot()
#Plot heatmap with pickup count
# Out:
# <Axes: >

# %%
# tlcMap[tlcMap['borough'] == 'Manhattan'].plot()

#Create heatmap of pickup location
pickup_heatmap = sns.jointplot(data=df, x='PULocationID', y='DOLocationID', kind='hex')

# %%
#Add trip count from df to the heatmap tlcmap
#join by df PU_locationid and tlcmap location_i
tlcMap['trip_count'] = df.groupby(df['PULocationID'])['PULocationID'].count()

# %%
df.groupby(df['PU_borough'])['PULocationID'].count()
# Out:
# PU_borough
# Bronx              911
# Brooklyn          7994
# EWR                  1
# Manhattan        37403
# Queens           17180
# Staten Island       12
# Unknown            198
# Name: PULocationID, dtype: int64

# %%
#Count trip count by zone: central park
df[df['PU_zone'] == 'Central Park']['PU_zone'].count()
# Out:
# 2847

# %%
#Plot map of manhattan with trip count as color gradient
tlcMap[tlcMap['borough'] == 'Manhattan'].plot(column='trip_count', cmap='RdPu', legend=True, figsize=(10,8), edgecolor='black')
plt.title('Trip Count by PickUp Location in Manhattan')
plt.show()

# %%
tlcMap[tlcMap['zone'] == 'Central Park']['trip_count']
# Out:
# 44   NaN
# Name: trip_count, dtype: float64

# %%
#Create a bla

# %%
#Plot geographic heatmap of trip_count over location_id
tlcMap.plot(column='trip_count', cmap='BuPu', legend=True, figsize=(12,8))
#Add lines to the edge
tlcMap.boundary.plot(color='black', linewidth=0.5, ax=plt.gca(), figsize=(15,10))
# Out:
# <Axes: >

# %%
#Plot geographic heatmap of trip_count over location_id group by borough
tlcMap.plot(column='trip_count', cmap='RdPu', legend=True, figsize=(12,8))

# %%
#Plot geographic heatmap of trip_count over borough
tlcMap.plot(column='DO_trip_count', cmap='RdPu', legend=True, figsize=(12,8))
#Add lines to the borough edge
tlcMap.boundary.plot(color='black', linewidth=0.5, ax=plt.gca(), figsize=(15,10))
#Annotate top 5 borough by trip counts with text annotation
# Out:
# <Axes: >
